# %%
#if it is necessary

# !pip install tensorflow-probability

# to generate gifs
# !pip install imageio
# !pip install git+https://github.com/tensorflow/docs
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Collecting tensorflow-probability
#   Downloading tensorflow_probability-0.24.0-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: absl-py in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-probability) (1.4.0)
# Requirement already satisfied: six>=1.10.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-probability) (1.16.0)
# Requirement already satisfied: numpy>=1.13.3 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-probability) (1.26.4)
# Requirement already satisfied: decorator in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-probability) (5.1.1)
# Requirement already satisfied: cloudpickle>=1.3 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-probability) (3.0.0)
# Requirement already satisfied: gast>=0.3.2 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: dm-tree in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-probability) (0.1.8)
# Downloading tensorflow_probability-0.24.0-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 27.6 MB/s eta 0:00:00 0:00:01
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Installing collected packages: tensorflow-probability
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Successfully installed tensorflow-probability-0.24.0
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Requirement already satisfied: imageio in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (2.35.1)
# Requirement already satisfied: numpy in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from imageio) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from imageio) (9.5.0)
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-3yqtto73
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/docs /tmp/pip-req-build-3yqtto73
#   Resolved https://github.com/tensorflow/docs to commit bd1c16109023bcf73755ee0e1552140bf377573c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: astor in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-docs==2024.10.14.18741) (0.8.1)
# Requirement already satisfied: absl-py in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-docs==2024.10.14.18741) (1.4.0)
# Requirement already satisfied: jinja2 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-docs==2024.10.14.18741) (3.1.2)
# Requirement already satisfied: nbformat in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-docs==2024.10.14.18741) (5.8.0)
# Requirement already satisfied: protobuf>=3.12 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-docs==2024.10.14.18741) (3.20.1)
# Requirement already satisfied: pyyaml in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow-docs==2024.10.14.18741) (6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from jinja2->tensorflow-docs==2024.10.14.18741) (2.1.2)
# Requirement already satisfied: fastjsonschema in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from nbformat->tensorflow-docs==2024.10.14.18741) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from nbformat->tensorflow-docs==2024.10.14.18741) (4.17.3)
# Requirement already satisfied: jupyter-core in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from nbformat->tensorflow-docs==2024.10.14.18741) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from nbformat->tensorflow-docs==2024.10.14.18741) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==2024.10.14.18741) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==2024.10.14.18741) (0.19.3)
# Requirement already satisfied: platformdirs>=2.5 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from jupyter-core->nbformat->tensorflow-docs==2024.10.14.18741) (3.2.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-2024.10.14.18741-py3-none-any.whl size=182608 sha256=cb9df389673f568f4ffc44e06ca177cf64e54a0f1de064a1a7593b3a0f1874c0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nu25hcvt/wheels/86/0f/1e/3b62293c8ffd0fd5a49508e6871cdb7554abe9c62afd35ec53
# Successfully built tensorflow-docs
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Installing collected packages: tensorflow-docs
#   Attempting uninstall: tensorflow-docs
#     Found existing installation: tensorflow-docs 2024.7.15.51478
#     Uninstalling tensorflow-docs-2024.7.15.51478:
#       Successfully uninstalled tensorflow-docs-2024.7.15.51478
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Successfully installed tensorflow-docs-2024.10.14.18741

# %%
# !pip install tf-keras
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Collecting tf-keras
#   Downloading tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tf-keras) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (23.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow<2.18,>=2.17->tf-keras)
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.66.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.18,>=2.17->tf-keras) (0.44.0)
# Requirement already satisfied: rich in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (13.3.3)
# Requirement already satisfied: namex in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2022.12.7)
# Requirement already satisfied: markdown>=2.6.8 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (2.1.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.1.2)
# Downloading tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.0 MB/s eta 0:00:00 0:00:01
# Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# Installing collected packages: protobuf, tf-keras
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
# WARNING: Ignoring invalid distribution -atplotlib (/mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.66.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.5 which is incompatible.
# onnx 1.12.0 requires protobuf<=3.20.1,>=3.12.2, but you have protobuf 4.25.5 which is incompatible.
# Successfully installed protobuf-4.25.5 tf-keras-2.17.0

# %%
from IPython import display

import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import tensorflow_probability as tfp
import time
# Out:
# 2024-10-16 10:31:10.298251: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-16 10:31:11.231692: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-16 10:31:11.571651: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-16 10:31:11.662281: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-16 10:31:12.376949: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-16 10:31:16.878333: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
train_images[0].shape
# Out:
# (28, 28, 1)

# %%
def preprocess_images(images):
  images = images.reshape((images.shape[0], 28, 28, 1)) / 255.
  return np.where(images > .5, 1.0, 0.0).astype('float32')

(train_images, _), (test_images, _) = tf.keras.datasets.mnist.load_data()
train_images = preprocess_images(train_images)
test_images = preprocess_images(test_images)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
train_size = 60000
batch_size = 32
test_size = 10000

train_dataset = (tf.data.Dataset.from_tensor_slices(train_images)
                 .shuffle(train_size).batch(batch_size))
test_dataset = (tf.data.Dataset.from_tensor_slices(test_images)
                .shuffle(test_size).batch(batch_size))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729085798.523642  210133 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-16 10:36:39.358384: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
class CVAE(tf.keras.Model):
  """Convolutional variational autoencoder."""

  def __init__(self, latent_dim):
    super(CVAE, self).__init__()
    self.latent_dim = latent_dim
    self.encoder = tf.keras.Sequential(
        [
            tf.keras.layers.InputLayer(input_shape=(28, 28, 1)),
            tf.keras.layers.Conv2D(
                filters=32, kernel_size=3, strides=(2, 2), activation='relu'),
            tf.keras.layers.Conv2D(
                filters=64, kernel_size=3, strides=(2, 2), activation='relu'),
            tf.keras.layers.Flatten(),
            # No activation
            tf.keras.layers.Dense(latent_dim + latent_dim),
        ]
    )

    self.decoder = tf.keras.Sequential(
        [
            tf.keras.layers.InputLayer(input_shape=(latent_dim,)),
            tf.keras.layers.Dense(units=7*7*32, activation=tf.nn.relu),
            tf.keras.layers.Reshape(target_shape=(7, 7, 32)),
            tf.keras.layers.Conv2DTranspose(
                filters=64, kernel_size=3, strides=2, padding='same',
                activation='relu'),
            tf.keras.layers.Conv2DTranspose(
                filters=32, kernel_size=3, strides=2, padding='same',
                activation='relu'),
            # No activation
            tf.keras.layers.Conv2DTranspose(
                filters=1, kernel_size=3, strides=1, padding='same'),
        ]
    )

  @tf.function
  def sample(self, eps=None):
    if eps is None:
      eps = tf.random.normal(shape=(100, self.latent_dim))
    return self.decode(eps, apply_sigmoid=True)

  def encode(self, x):
    mean, logvar = tf.split(self.encoder(x), num_or_size_splits=2, axis=1)
    return mean, logvar

  def reparameterize(self, mean, logvar):
    eps = tf.random.normal(shape=mean.shape)
    return eps * tf.exp(logvar * .5) + mean

  def decode(self, z, apply_sigmoid=False):
    logits = self.decoder(z)
    if apply_sigmoid:
      probs = tf.sigmoid(logits)
      return probs
    return logits

# %%
optimizer = tf.keras.optimizers.Adam(1e-4)


def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis)


def compute_loss(model, x):
  mean, logvar = model.encode(x)
  z = model.reparameterize(mean, logvar)
  x_logit = model.decode(z)
  cross_ent = tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit, labels=x)
  logpx_z = -tf.reduce_sum(cross_ent, axis=[1, 2, 3])
  logpz = log_normal_pdf(z, 0., 0.)
  logqz_x = log_normal_pdf(z, mean, logvar)
  return -tf.reduce_mean(logpx_z + logpz - logqz_x)


@tf.function
def train_step(model, x, optimizer):
  """Executes one training step and returns the loss.

  This function computes the loss and gradients, and uses the latter to
  update the model's parameters.
  """
  with tf.GradientTape() as tape:
    loss = compute_loss(model, x)
  gradients = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
epochs = 5
# set the dimensionality of the latent space to a plane for visualization later
latent_dim = 2
num_examples_to_generate = 16

# keeping the random vector constant for generation (prediction) so
# it will be easier to see the improvement.
random_vector_for_generation = tf.random.normal(
    shape=[num_examples_to_generate, latent_dim])
model = CVAE(latent_dim)
# Out:
# /mnt/d/codigos/posdoc/CMS-ML-analysis/.cmsml/lib/python3.10/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
def generate_and_save_images(model, epoch, test_sample):
  mean, logvar = model.encode(test_sample)
  z = model.reparameterize(mean, logvar)
  predictions = model.sample(z)
  fig = plt.figure(figsize=(4, 4))

  for i in range(predictions.shape[0]):
    plt.subplot(4, 4, i + 1)
    plt.imshow(predictions[i, :, :, 0], cmap='gray')
    plt.axis('off')

  # tight_layout minimizes the overlap between 2 sub-plots
  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %%
tf.config.run_functions_eagerly(True)

# Pick a sample of the test set for generating output images
assert batch_size >= num_examples_to_generate
for test_batch in test_dataset.take(1):
  test_sample = test_batch[0:num_examples_to_generate, :, :, :]

tf.config.run_functions_eagerly(False)
# Out:
# 2024-10-16 10:37:38.115233: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
generate_and_save_images(model, 0, test_sample)

for epoch in range(1, epochs + 1):
  start_time = time.time()
  for train_x in train_dataset:
    train_step(model, train_x, optimizer)
  end_time = time.time()

  loss = tf.keras.metrics.Mean()
  for test_x in test_dataset:
    loss(compute_loss(model, test_x))
  elbo = -loss.result()
  display.clear_output(wait=False)
  print('Epoch: {}, Test set ELBO: {}, time elapse for current epoch: {}'
        .format(epoch, elbo, end_time - start_time))
  generate_and_save_images(model, epoch, test_sample)
# Out:
# Epoch: 5, Test set ELBO: -161.22213745117188, time elapse for current epoch: 8.411097288131714

# %%
def display_image(epoch_no):
  return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))

# %%
plt.imshow(display_image(epoch))
plt.axis('off')  # Display images
# Out:
# (-0.5, 399.5, 399.5, -0.5)

# %%
anim_file = 'cvae.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('image*.png')
  filenames = sorted(filenames)
  for filename in filenames:
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)
# Out:
# /tmp/ipykernel_210133/1290275450.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# /tmp/ipykernel_210133/1290275450.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)

# %%
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_file)
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
def plot_latent_images(model, n, digit_size=28):
  """Plots n x n digit images decoded from the latent space."""

  norm = tfp.distributions.Normal(0, 1)
  grid_x = norm.quantile(np.linspace(0.05, 0.95, n))
  grid_y = norm.quantile(np.linspace(0.05, 0.95, n))
  image_width = digit_size*n
  image_height = image_width
  image = np.zeros((image_height, image_width))

  for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
      z = np.array([[xi, yi]])
      x_decoded = model.sample(z)
      digit = tf.reshape(x_decoded[0], (digit_size, digit_size))
      image[i * digit_size: (i + 1) * digit_size,
            j * digit_size: (j + 1) * digit_size] = digit.numpy()

  plt.figure(figsize=(10, 10))
  plt.imshow(image, cmap='Greys_r')
  plt.axis('Off')
  plt.show()

# %%
plot_latent_images(model, 20)
